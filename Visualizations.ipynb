# %% [markdown]
# ## Evaluation by Classification Accuracy

# %%
import matplotlib.pyplot as plt
accuracy = dict()
accuracy["Decision_Tree"] = 0.02528735632183908
accuracy["Naive_Bayes"] = 0.535632183908046
accuracy["Gradient_Boost"] = 0.8436781609195402
accuracy["Logistic_Regression"] = 0.8781609195402299
accuracy["Linear_Support_Vector"] = 0.8781609195402299
accuracy["Random_Forest"] = 0.8551724137931035

# %%
bar_width = 0.4
plt.figure(figsize=(12,6))
plt.bar(range(len(accuracy)),accuracy.values(),bar_width,align='center')
plt.xticks(range(len(accuracy)), accuracy.keys(),fontweight='bold')
plt.xlabel('Classification Model',fontsize=14,fontweight='bold')
plt.ylabel('Accuracy Score',fontsize=14,fontweight='bold')
plt.title('Performance of Classifers by Accuracy',fontsize=16,fontweight='bold')
plt.show()

# %% [markdown]
# ## Evaluation by Execution Times

# %%
execution_time = dict()
execution_time["Decision_Tree"] = 2.38758263
execution_time["Naive_Bayes"] = 2.077322316
execution_time["Gradient_Boost"] = 5.713710709
execution_time["Logistic_Regression"] = 4.458577756
execution_time["Linear_Support_Vector"] = 3.413597394
execution_time["Random_Forest"] = 1.437155352

# %%
bar_width = 0.4
plt.figure(figsize=(12,6))
plt.bar(range(len(execution_time)),execution_time.values(),bar_width,align='center')
plt.xticks(range(len(execution_time)), execution_time.keys(),fontweight='bold')
plt.xlabel('Classification Model',fontsize=14,fontweight='bold')
plt.ylabel('Total Execution Time',fontsize=14,fontweight='bold')
plt.title('Total Execution Times of Classification Models',fontsize=16,fontweight='bold')
plt.show()

# %% [markdown]
# ## Feature Importance Using Random Forest Model

# %%
feature_importance_rf = dict()
feature_importance_rf["EducationFieldIndexed"] = 0.1530923924827993
feature_importance_rf["WorkLifeBalance"] = 0.1023278904056357
feature_importance_rf["JobLevel"] = 0.07167136494461042
feature_importance_rf["EmployeeCount"] = 0.05353818139274179
feature_importance_rf["YearsSinceLastPromotion"] = 0.05341720626256577
feature_importance_rf["JobSatisfaction"] = 0.04839627168119147
feature_importance_rf["MonthlyRate"] = 0.047178943187819525
feature_importance_rf["DailyRate"] = 0.04443893878047191
feature_importance_rf["TotalWorkingYears"] = 0.04007731162630204
feature_importance_rf["JobInvolvement"] = 0.03388571890578073
feature_importance_rf["EmployeeNumber"] = 0.032904507937286866
feature_importance_rf["StandardHours"] = 0.03137696545725281
feature_importance_rf["StockOptionLevel"] = 0.030763531015013376
feature_importance_rf["PerformanceRating"] = 0.028361086356872543
feature_importance_rf["Over18Indexed"] = 0.028293851985025497
feature_importance_rf["EnvironmentSatisfaction"] = 0.026438481211019403
feature_importance_rf["MonthlyIncome"] = 0.023936233638646606
feature_importance_rf["JobRoleIndexed"] = 0.023641377041299795
feature_importance_rf["BusinessTravelIndexed"] = 0.022553860464860267
feature_importance_rf["OverTimeIndexed"] = 0.021640636282649457
feature_importance_rf["DepartmentIndexed"] = 0.017276171763616236
feature_importance_rf["NumCompaniesWorked"] = 0.013396179193459194
feature_importance_rf["DistanceFromHome"] = 0.012993469004396987
feature_importance_rf["AttritionIndexed"] = 0.011745346545736175
feature_importance_rf["GenderIndexed"] = 0.01133758114796403
feature_importance_rf["YearsAtCompany"] = 0.010140778076189561
feature_importance_rf["MaritalStatusIndexed"] = 0.005175723208792475
feature_importance_rf["DailyRate"] = 0.0
feature_importance_rf["Education"] = 0.0
feature_importance_rf["HourlyRate"] = 0.0
feature_importance_rf["PercentSalaryHike"] = 0.0
feature_importance_rf["RelationshipSatisfaction"] = 0.0
feature_importance_rf["TrainingTimesLastYear"] = 0.0
feature_importance_rf["YearsInCurrentRole"] = 0.0

# %%
bar_width = 0.5
plt.figure(figsize=(8,10))
plt.barh(range(len(feature_importance_rf)),feature_importance_rf.values(),bar_width,align='center')
plt.yticks(range(len(feature_importance_rf)), feature_importance_rf.keys(),fontweight='bold')
plt.xlabel('Importance Score',fontsize=14,fontweight='bold')
plt.ylabel('Feature',fontsize=14,fontweight='bold')
plt.title('Feature Ranking Using Random Forest Model',fontsize=16,fontweight='bold')
plt.show()

# %% [markdown]
# ## Feature Importance Using Gradient Boosting Classifier

# %%
feature_importance_gbt = dict()
feature_importance_gbt["DistanceFromHome"] = 0.11797784916758056
feature_importance_gbt["DailyRate"] = 0.06982757169383472
feature_importance_gbt["JobSatisfaction"] = 0.06482526363226403
feature_importance_gbt["EmployeeNumber"] = 0.062483682513335026
feature_importance_gbt["StockOptionLevel"] = 0.057804711317213854
feature_importance_gbt["OverTimeIndexed"] = 0.05129937458585465
feature_importance_gbt["YearsAtCompany"] = 0.05058183108455483
feature_importance_gbt["TotalWorkingYears"] = 0.046574206923370456
feature_importance_gbt["EmployeeCount"] = 0.0465656051999383
feature_importance_gbt["RelationshipSatisfaction"] = 0.04519364752057757
feature_importance_gbt["MonthlyRate"] = 0.03655772903042963
feature_importance_gbt["GenderIndexed"] = 0.0355536597612214
feature_importance_gbt["PercentSalaryHike"] = 0.032994823943030833
feature_importance_gbt["EnvironmentSatisfaction"] = 0.03233038034102215
feature_importance_gbt["MonthlyIncome"] = 0.030514015317902942
feature_importance_gbt["JobRoleIndexed"] = 0.027744199928241585
feature_importance_gbt["NumCompaniesWorked"] = 0.02445695506948601
feature_importance_gbt["MaritalStatusIndexed"] = 0.023662259316405365
feature_importance_gbt["WorkLifeBalance"] = 0.022581952596380534
feature_importance_gbt["BusinessTravelIndexed"] = 0.019796040684960832
feature_importance_gbt["YearsSinceLastPromotion"] = 0.018783027358766254
feature_importance_gbt["JobLevel"] = 0.01405111869061565
feature_importance_gbt["Age"] = 0.01388488258803306
feature_importance_gbt["YearsInCurrentRole"] = 0.012855763914586127
feature_importance_gbt["Over18Indexed"] = 0.012002053794981801
feature_importance_gbt["HourlyRate"] = 0.011561198053813133
feature_importance_gbt["Education"] = 0.00796872542886304
feature_importance_gbt["TrainingTimesLastYear"]  = 0.006752333053982931
feature_importance_gbt["YearsWithCurrManager"] = 0.002552271215365082
feature_importance_gbt["DepartmentIndexed"] = 2.628662733876714E-4
feature_importance_gbt["EducationFieldIndexed"] =0.0
feature_importance_gbt["JobInvolvement"] = 0.0
feature_importance_gbt["PerformanceRating"] = 0.0
feature_importance_gbt["StandardHours"] = 0.0

# %%
bar_width = 0.5
plt.figure(figsize=(8,10))
plt.barh(range(len(feature_importance_gbt)),feature_importance_gbt.values(),bar_width,align='center')
plt.yticks(range(len(feature_importance_gbt)), feature_importance_gbt.keys(),fontweight='bold')
plt.xlabel('Importance Score',fontsize=14,fontweight='bold')
plt.ylabel('Feature',fontsize=14,fontweight='bold')
plt.title('Feature Ranking Using Gradient Boosting Classifier',fontsize=16,fontweight='bold')
plt.show()
